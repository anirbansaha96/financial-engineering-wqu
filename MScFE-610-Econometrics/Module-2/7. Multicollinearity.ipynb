# %% [markdown]
# # Multicollinearity
# Multicollinearity is the occurrence of high intercorrelations among two or more independent variables in a multiple regression model.
# In general, multicollinearity can lead to wider confidence intervals that produce less reliable probabilities in terms of the effect of independent variables in a model. That is, the statistical inferences from a model with multicollinearity may not be dependable.
# It makes it hard for interpretation of model and also creates overfitting problem. When independent variables are highly correlated, change in one variable would cause change to another and so the model results fluctuate significantly. The model results will be unstable and vary a lot given a small change in the data or model.

# %% [markdown]
# ### How to check for Multicollinearity:
# #### 1. Checking Correlation Matrix

# %%
import pandas as pd
from sklearn.datasets import load_boston
import statsmodels.api as sm
boston=load_boston()
X = pd.DataFrame(data=boston.data,columns=boston.feature_names)
Y = pd.DataFrame(data=boston.target,columns=['MEDV'])

# %%
corr=X.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row0_col1 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row0_col2 {
#             background-color:  #f7bca1;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row0_col3 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row0_col4 {
#             background-color:  #f7b599;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row0_col5 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row0_col6 {
#             background-color:  #f5c2aa;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row0_col7 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row0_col8 {
#             background-color:  #f49a7b;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row0_col9 {
#             background-color:  #f6a283;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row0_col10 {
#             background-color:  #dadce0;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row0_col11 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row0_col12 {
#             background-color:  #f7b99e;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row1_col0 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row1_col2 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row1_col3 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row1_col4 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row1_col5 {
#             background-color:  #edd1c2;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row1_col6 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row1_col7 {
#             background-color:  #ec7f63;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row1_col8 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row1_col9 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row1_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row1_col11 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row1_col12 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row2_col0 {
#             background-color:  #edd1c2;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row2_col1 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row2_col3 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row2_col4 {
#             background-color:  #e0654f;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row2_col5 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row2_col6 {
#             background-color:  #ee8669;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row2_col7 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row2_col8 {
#             background-color:  #f6a283;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row2_col9 {
#             background-color:  #ea7b60;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row2_col10 {
#             background-color:  #ead4c8;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row2_col11 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row2_col12 {
#             background-color:  #f39778;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row3_col0 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row3_col1 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row3_col2 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row3_col4 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row3_col5 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row3_col6 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row3_col7 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row3_col8 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row3_col9 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row3_col10 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row3_col11 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row3_col12 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row4_col0 {
#             background-color:  #efcfbf;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row4_col1 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row4_col2 {
#             background-color:  #e16751;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row4_col3 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row4_col5 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row4_col6 {
#             background-color:  #e46e56;
#             color:  #000000;
#         }    #T_9e7bdd34_2289_11eb_b30b_dba2c0759d76row4_col7 {
#             background-color:  #3b4cc0;
#             color:

# %% [markdown]
# As we can see the features "Tax" and "Indus" are highly correlated, "Age" and "Nox" are highly correlated.

# %% [markdown]
# #### 1. Variance Inflation Factor (VIF)
# It is a measure of multi-collinearity in the set of multiple regression variables. The higher the value of VIF the higher correlation between this variable and the rest.
# In VIF method, we pick each feature and regress it against all of the other features. For each regression, the factor is calculated as :
# $$ VIF=\frac{1}{1-R^2}$$
# Generally, a VIF above 5 indicates a high multicollinearity.

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

newdf = dataset.select_dtypes(include=numerics)
newdf.fillna(newdf.mean);

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor 
X=sm.add_constant(X)
# VIF dataframe 
vif_data = pd.DataFrame() 
vif_data["feature"] = X.columns 

# calculating VIF for each feature 
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))] 

print(vif_data)
# Out:
#     feature    VIF
# 0     const 585.27
# 1      CRIM   1.79
# 2        ZN   2.30
# 3     INDUS   3.99
# 4      CHAS   1.07
# 5       NOX   4.39
# 6        RM   1.93
# 7       AGE   3.10
# 8       DIS   3.96
# 9       RAD   7.48
# 10      TAX   9.01
# 11  PTRATIO   1.80
# 12        B   1.35
# 13    LSTAT   2.94

# %% [markdown]
# We get a value Infinity when $R^2$ is 1, indicating perfect multicollinearity.
# As we see RAD, TAX are highly correlated with the other variables.

# %% [markdown]
# One approach may be the removal of regressors that are correlated.  Another may be principal component analysis or PCA.
